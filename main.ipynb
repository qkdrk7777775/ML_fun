# %%
import gridSearch

# %%
from BorutaShap import BorutaShap, load_data
from sklearn.model_selection import train_test_split

X, y = load_data(data_type='regression')
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 166  2.01019   0.0  19.58   0.0  0.605  7.929  96.2  2.0459   5.0  403.0
# 304  0.05515  33.0   2.18   0.0  0.472  7.236  41.1  4.0220   7.0  222.0
# 192  0.08664  45.0   3.44   0.0  0.437  7.178  26.3  6.4798   5.0  398.0
# 111  0.10084   0.0  10.01   0.0  0.547  6.715  81.6  2.6775   6.0  432.0
# 397  7.67202   0.0  18.10   0.0  0.693  5.747  98.9  1.6334  24.0  666.0
#
#      PTRATIO       B  LSTAT
# 166     14.7  369.30   3.70
# 304     18.4  393.68   6.93
# 192     15.2  390.49   2.87
# 111     17.8  395.59  10.16
# 397     20.2  393.10  19.92

# %%
Randomize=gridSearch.TreeSearchCV()

# %%
models=Randomize.tree_Randomized_search_regressor(SetSeed=1,N_job=3)

# %%
models['AdaBoostRegressor']
# Out:
# GridSearchCV(cv=3, estimator=AdaBoostRegressor(random_state=1), n_jobs=3,
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.3, 1],
#                          'loss': ['ls', 'lad', 'huber', 'linear', 'square',
#                                   'exponential'],
#                          'n_estimators': [100, 500, 900]},
#              return_train_score=True, scoring='neg_mean_absolute_error')

# %%
for name, model in models.items():
    print(name)
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    best_parameter=model.best_params_
# Out:
# AdaBoostRegressor
# DecisionTreeRegressor
# RandomForestRegressor
# ExtraTreesRegressor
# GradientBoostingRegressor
# LightGBMRegressor
# CatBoostRegressor
# 0:	learn: 9.2973535	total: 51ms	remaining: 51s
# 1:	learn: 9.2375927	total: 53.1ms	remaining: 26.5s
# 2:	learn: 9.1717762	total: 54.8ms	remaining: 18.2s
# 3:	learn: 9.1057428	total: 56.5ms	remaining: 14.1s
# 4:	learn: 9.0454386	total: 58.3ms	remaining: 11.6s
# 5:	learn: 8.9877474	total: 60ms	remaining: 9.95s
# 6:	learn: 8.9310297	total: 61.7ms	remaining: 8.75s
# 7:	learn: 8.8749854	total: 63.4ms	remaining: 7.86s
# 8:	learn: 8.8187047	total: 65ms	remaining: 7.16s
# 9:	learn: 8.7679626	total: 66.6ms	remaining: 6.59s
# 10:	learn: 8.7149125	total: 68.2ms	remaining: 6.13s
# 11:	learn: 8.6548298	total: 69.8ms	remaining: 5.75s
# 12:	learn: 8.5966440	total: 71.4ms	remaining: 5.42s
# 13:	learn: 8.5426338	total: 73ms	remaining: 5.14s
# 14:	learn: 8.4945090	total: 74.6ms	remaining: 4.9s
# ...

# %%
for name, model in models.items():
    model.fit(X_train, Y_train)
    pred = model.predict(X_test)
    best_parameter=model.best_params_
    pd.concat([pd.DataFrame.from_dict(best_parameter,orient='index').T,
               pd.DataFrame.from_dict({'model_name':[name][0]},orient='index').T],axis=1).to_csv(
        f'{SCORES_PATH}/pca_randomizeSearch/{name}_best_param_shift{lag_hr}_pred{hr}.csv')
    df_pred = pd.DataFrame()
    df_pred['target'] = test['target']
    df_pred['prediction'] = pred
    df_pred['bias'] = df_pred['target'] - df_pred['prediction']
    metrics = pred_performace(df_pred)
    #pd.DataFrame(metrics)
    pd.DataFrame.from_dict(metrics,orient='index').T.to_csv(f'{SCORES_PATH}/pca_randomizeSearch/{name}_result_shift{lag_hr}_pred{hr}.csv')
    df_pred.to_csv(f'{SCORES_PATH}/pca_randomizeSearch/{name}_predict_value_shift{lag_hr}_pred{hr}.csv')
